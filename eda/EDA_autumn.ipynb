# %% [markdown]
# ## Imports

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

import numpy as np

# %% [markdown]
# ## Load Data

# %%
df = pd.read_csv("../data/sep_oct_nov_autumn_dataset.csv")

# %%
df.head()
# Out:
#        s_date  s_hour  day_of_week  week_of_month weekend_or_weekday_sdate  \
# 0  2023-09-14      23            3              2                  weekday
# 1  2023-09-14      23            3              2                  weekday
# 2  2023-09-14      23            3              2                  weekday
# 3  2023-09-14      23            3              2                  weekday
# 4  2023-09-14      23            3              2                  weekday
#
#    is_holiday time_of_day  peak_off_peak  start_station_number  longitude  \
# 0       False       night              0                  3455  -0.113856
# 1       False       night              0                  1045  -0.076793
# 2       False       night              0                  1040  -0.100791
# 3       False       night              0                  1207  -0.120719
# 4       False       night              0                200212  -0.103079
#
#    ...  dist_to_nearest_library  dist_to_nearest_cinema  \
# 0  ...               444.935826              817.903121
# 1  ...               488.893796              773.627644
# 2  ...               654.085035              705.760977
# 3  ...               540.130343              610.777430
# 4  ...               339.011747             1375.236673
#
#    dist_to_nearest_supermarket  dist_to_nearest_station  \
# 0                  1047.439097               146.125704
# 1                   669.629555               248.362702
# 2                   541.597444               429.613694
# 3                   696.515163               375.363608
# 4                   770.357372                80.973029
#
#    dist_to_nearest_platform  dist_to_nearest_stop_position  \
# 0                124.324872                     111.913501
# 1                172.767545                     172.767545
# 2                254.779587                     295.141664
# 3                 95.201584                     154.727792
# 4                 43.340715                      94.426292
#
#    dist_to_nearest_railway_station  dist_to_nearest_bus_stop  month  count
# 0                       146.125704                124.324872      1      1
# 1                       248.362702                172.767545      1      1
# 2                       429.613694                323.852381      1      1
# 3                       375.363608                 95.201584      1      2
# 4                        80.973029                 43.340715      1      5
#
# [5 rows x 45 columns]

# %%
print("Number Of Stations: {0}".format(len(df["start_station_number"].unique())))
# Out:
# Number Of Stations: 100

# %%
num = 1

print("All Column Names: ")
for column in df.columns:
    print(f"\t{num}) " + column)
    num += 1
# Out:
# All Column Names:
# 	1) s_date
# 	2) s_hour
# 	3) day_of_week
# 	4) week_of_month
# 	5) weekend_or_weekday_sdate
# 	6) is_holiday
# 	7) time_of_day
# 	8) peak_off_peak
# 	9) start_station_number
# 	10) longitude
# 	11) latitude
# 	12) cafe_count_5min_walk
# 	13) atm_count_5min_walk
# 	14) pub_count_5min_walk
# 	15) school_count_5min_walk
# 	16) university_count_5min_walk
# 	17) college_count_5min_walk
# 	18) bank_count_5min_walk
# 	19) post_office_count_5min_walk
# 	20) library_count_5min_walk
# 	21) cinema_count_5min_walk
# 	22) supermarket_count_5min_walk
# 	23) station_count_5min_walk
# 	24) platform_count_5min_walk
# 	25) stop_position_count_5min_walk
# 	26) railway_station_count_5min_walk
# 	27) highway_bus_stop_count_5min_walk
# 	28) dist_to_nearest_cafe
# 	29) dist_to_nearest_atm
# 	30) dist_to_nearest_pub
# 	31) dist_to_nearest_school
# 	32) dist_to_nearest_university
# 	33) dist_to_nearest_college
# 	34) dist_to_nearest_bank
# 	35) dist_to_nearest_post_office
# 	36) dist_to_nearest_library
# 	37) dist_to_nearest_cinema
# 	38) dist_to_nearest_supermarket
# 	39) dist_to_nearest_station
# 	40) dist_to_nearest_platform
# 	41) dist_to_nearest_stop_position
# 	42) dist_to_nearest_railway_station
# 	43) dist_to_nearest_bus_stop
# 	44) month
# 	45) count

# %%
# len(df["latitude"].unique())
print( f"Number of Rows with N/A Values: {len(df[df.isna().any(axis=1)])}")
# Out:
# Number of Rows with N/A Values: 0

# %%
missing_lat_stations = df[df['latitude'].isnull()]['start_station_number'].tolist()

print("Station numbers with missing latitude:", missing_lat_stations)
# Out:
# Station numbers with missing latitude: []

# %%
print(df.info()) 
print(df.describe())  
print(df.nunique())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 218400 entries, 0 to 218399
# Data columns (total 45 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   s_date                            218400 non-null  object
#  1   s_hour                            218400 non-null  int64
#  2   day_of_week                       218400 non-null  int64
#  3   week_of_month                     218400 non-null  int64
#  4   weekend_or_weekday_sdate          218400 non-null  object
#  5   is_holiday                        218400 non-null  bool
#  6   time_of_day                       218400 non-null  object
#  7   peak_off_peak                     218400 non-null  int64
#  8   start_station_number              218400 non-null  int64
#  9   longitude                         218400 non-null  float64
#  10  latitude                          218400 non-null  float64
#  11  cafe_count_5min_walk              218400 non-null  int64
#  12  atm_count_5min_walk               218400 non-null  int64
#  13  pub_count_5min_walk               218400 non-null  int64
#  14  school_count_5min_walk            218400 non-null  int64
#  15  university_count_5min_walk        218400 non-null  int64
#  16  college_count_5min_walk           218400 non-null  int64
#  17  bank_count_5min_walk              218400 non-null  int64
#  18  post_office_count_5min_walk       218400 non-null  int64
#  19  library_count_5min_walk           218400 non-null  int64
#  20  cinema_count_5min_walk            218400 non-null  int64
#  21  supermarket_count_5min_walk       218400 non-null  int64
#  22  station_count_5min_walk           218400 non-null  int64
#  23  platform_count_5min_walk          218400 non-null  int64
#  24  stop_position_count_5min_walk     218400 non-null  int64
#  25  railway_station_count_5min_walk   218400 non-null  int64
#  26  highway_bus_stop_count_5min_walk  218400 non-null  int64
#  27  dist_to_nearest_cafe              218400 non-null  float64
#  28  dist_to_nearest_atm               218400 non-null  float64
#  29  dist_to_nearest_pub               218400 non-null  float64
#  30  dist_to_nearest_school            218400 non-null  float64
#  31  dist_to_nearest_university        218400 non-null  float64
#  32  dist_to_nearest_college           218400 non-null  float64
#  33  dist_to_nearest_bank              218400 non-null  float64
#  34  dist_to_nearest_post_office       218400 non-null  float64
#  35  dist_to_nearest_library           218400 non-null  float64
#  36  dist_to_nearest_cinema            218400 non-null  float64
#  37  dist_to_nearest_supermarket       218400 non-null  float64
#  38  dist_to_nearest_station           218400 non-null  float64
#  39  dist_to_nearest_platform          218400 non-null  float64
#  40  dist_to_nearest_stop_position     218400 non-null  float64
#  41  dist_to_nearest_railway_station   218400 non-null  float64
#  42  dist_to_nearest_bus_stop          218400 non-null  float64
#  43  month                             218400 non-null  int64
#  44  count                             218400 non-null  int64
# dtypes: bool(1), float64(18), int64(23), object(3)
# memory usage: 73.5+ MB
# None
#               s_hour    day_of_week  week_of_month  peak_off_peak  \
# count  218400.000000  218400.000000  218400.000000  218400.000000
# mean       11.500000       3.000000       2.692308       0.095238
# std         6.922202       2.000005       1.263978       0.293544
# min         0.000000       0.000000       1.000000       0.000000
# 25%         5.750000       1.000000       2.000000       0.000000
# 50%        11.500000       3.000000       3.000000       0.000000
# 75%        17.250000       5.000000       4.000000       0.000000
# max        23.000000       6.000000       5.000000       1.000000
#
#        start_station_number      longitude       latitude  \
# count         218400.000000  218400.000000  218400.000000
# mean           63807.360000      -0.100066      51.513964
# std           109393.039537       0.012003       0.006982
# min              959.000000      -0.120909      51.500296
# 25%             1043.750000      -0.109656      51.507350
# 50%             1191.500000      -0.099692      51.514696
# 75%            66646.000000      -0.091263      51.519161
# max           300250.000000      -0.076793      51.526718
#
#        cafe_count_5min_walk  atm_count_5min_walk  pub_count_5min_walk  ...  \
# count         218400.000000        218400.000000        218400.000000  ...
# mean               5.680000             1.740000             1.680000  ...
# std                4.886482             2.066983             1.660606  ...
# min                0.000000             0.000000             0.000000  ...
# 25%                2.000000             0.000000             0.000000  ...
# 50%                5.000000             1.000000             1.000000  ...
# 75%                8.000000             2.000000             2.250000  ...
# max               24.000000             9.000000             8.000000  ...
#
#        dist_to_nearest_library  dist_to_nearest_cinema  \
# count            218400.000000           218400.000000
# mean                553.388687              708.432101
# std                 270.361443              346.869637
# min                  29.548317               23.773957
# 25%                 340.085991              482.784488
# 50%                 524.610896              724.970287
# 75%                 772.574725              953.036237
# max                1181.905221             1375.236673
#
#        dist_to_nearest_supermarket  dist_to_nearest_station  \
# count                218400.000000            218400.000000
# mean                    494.045955               388.110252
# std                     259.624761               174.848791
# min                      25.929076                25.671667
# 25%                     299.094237               264.437294
# 50%                     452.028907               381.234625
# 75%                     665.632032               501.323729
# max                    1082.109584               893.195096
#
#        dist_to_nearest_platform  dist_to_nearest_stop_position  \
# count             218400.000000                  218400.000000
# mean                 134.686680                     151.874977
# std                   92.440303                     103.374611
# min                    0.000000                       0.000000
# 25%                   62.312146                      69.964266
# 50%                  124.149141                     146.506827
# 75%                  197.772619                     211.268657
# max                  430.360583                     459.659139
#
#        dist_to_nearest_railway_station  dist_to_nearest_bus_stop       month  \
# count                    218400.000000             218400.000000  218400.000
# mean                        388.799048                138.743473       2.000
# std                         174.445953                 94.135019       0.812
# min                          25.671667                  0.000000       1.000
# 25%                         269.316314                 66.463673       1.000
# 50%                         381.234625                127.243442       2.000
# 75%                         501.323729                198.887880       3.000
# max                         893.195096                430.360583       3.000
#
#                count
# count  218400.000000
# mean        1.648141
# std         3.654839
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         2.000000
# max       154.000000
#
# [8 rows x 41 columns]
# s_date                               91
# s_hour                               24
# day_of_week                           7
# week_of_month                         5
# weekend_or_weekday_sdate              2
# is_holiday                            1
# time_of_day                           4
# peak_off_peak                         2
# start_station_number                100
# longitude                           100
# latitude                            100
# cafe_count_5min_walk                 20
# atm_count_5min_walk                  10
# pub_count_5min_walk                   8
# school_count_5min_walk                2
# university_count_5min_walk            2
# college_count_5min_walk               2
# bank_count_5min_walk                  4
# post_office_count_5min_walk           3
# library_count_5min_walk               3
# cinema_count_5min_walk                2
# supermarket_count_5min_walk           4
# station_count_5min_walk               3
# platform_count_5min_walk             20
# stop_position_count_5min_walk        22
# railway_station_count_5min_walk       3
# highway_bus_stop_count_5min_walk     21
# dist_to_nearest_cafe                 98
# dist_to_nearest_atm                  99
# dist_to_nearest_pub                 100
# dist_to_nearest_school              100
# dist_to_nearest_university          100
# dist_to_nearest_college             100
# dist_to_nearest_bank                100
# dist_to_nearest_post_office         100
# dist_to_nearest_library             100
# dist_to_nearest_cinema              100
# dist_to_nearest_supermarket         100
# dist_to_nearest_station             100
# dist_to_nearest_platform             98
# dist_to_nearest_stop_position        95
# dist_to_nearest_railway_station     100
# dist_to_nearest_bus_stop             98
# month                                 3
# count                               120
# dtype: int64

# %%
df['log_count'] = np.log10(df['count']) # Log Transformed Y
# Out:
# C:\Users\USER\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
plt.figure(figsize=(12,6))
sns.histplot(df['log_count'])
plt.title('Distribution of Bike Rents')
plt.show()

# %% [markdown]
# ### Demand For Each Day Of The Week

# %%
temp_df = df.groupby("day_of_week")["count"].sum().reset_index()
print(temp_df)

plt.bar(x = "day_of_week", height="count", data=temp_df, color=["#2ca02c", "#2ca02c", "#2ca02c", "#2ca02c","#2ca02c","#1f77b4", "#1f77b4"])
plt.title("day of the week vs count".title())
plt.xticks(labels=["Mon", "Tue", "Wed", "Thu", "Fri", "Sat", "Sun"], ticks=(1,2,3,4,5,6,7))
plt.show()
# Out:
#    day_of_week  count
# 0            0  59420
# 1            1  69359
# 2            2  61743
# 3            3  64356
# 4            4  49221
# 5            5  30469
# 6            6  25386

# %% [markdown]
# ### Demand For Day Of The Week And Week Of The Month

# %%
fig, ax = plt.subplots(2,2, figsize=(15,5))
sns.boxplot(x='day_of_week', y='count', data=df, ax=ax[0][0])
sns.boxplot(x='week_of_month', y='count', data=df, ax=ax[0][1])
sns.boxplot(x='day_of_week', y='log_count', data=df, ax=ax[1][0])
sns.boxplot(x='week_of_month', y='log_count', data=df, ax=ax[1][1])

ax[0][0].set_title('day of week vs count'.title())
ax[0][1].set_title('week of the month vs count'.title())
ax[1][0].set_title('day of week vs log count'.title())
ax[1][1].set_title('week of the month vs log count'.title())

plt.subplots_adjust(
    left=0.1,    
    right=0.9,   
    bottom=0.1,  
    top=0.9,     
    wspace=0.6,  
    hspace=0.6   
)

plt.show()

# %% [markdown]
# ### Demand For Weekdays and Weekends

# %%
temp_df = df.groupby("weekend_or_weekday_sdate")["count"].sum().reset_index()

print(temp_df)

plt.bar(x = "weekend_or_weekday_sdate", height="count", data=temp_df, color=["#1f77b4","#d62728"])
plt.xticks(ticks=(0,1))
plt.title("week day and weekend vs count".title())
plt.show()
# Out:
#   weekend_or_weekday_sdate   count
# 0                  weekday  304099
# 1                  weekend   55855

# %% [markdown]
# ### Demand For Time Of The Day

# %%
temp_df = df.groupby("time_of_day")["count"].sum().reset_index()
print(temp_df)

sns.barplot(x = "time_of_day", y="count", data=temp_df, hue="time_of_day")

plt.show()
# Out:
#   time_of_day   count
# 0         day  144195
# 1     evening   95667
# 2     morning   97826
# 3       night   22266

# %% [markdown]
# ### Demand For Peak And Off Peak Times

# %%
temp_df = df.groupby("peak_off_peak").agg({"count":"sum"})

print(temp_df)
sns.barplot(x='peak_off_peak', y='count', data=temp_df, hue="peak_off_peak")
plt.title("peak or off peak vs count".title())
plt.show()
# Out:
#                 count
# peak_off_peak
# 0              326036
# 1               33918

# %% [markdown]
# ### Demand For Each Hour

# %%
fig, ax = plt.subplots(1,2, figsize=(15,5))
sns.boxplot(x='s_hour', y='count', data=df, ax=ax[0])
ax[0].set_title('Count by Hour')

sns.boxplot(x='s_hour', y='log_count', data=df, ax=ax[1])
ax[1].set_title('Log Count by Hour')
plt.show()

# %%
hourly_trend = df.groupby(['s_hour', 'weekend_or_weekday_sdate'])['count'].sum().reset_index()

plt.figure(figsize=(14, 6))
sns.lineplot(data=hourly_trend, x='s_hour', y='count', hue='weekend_or_weekday_sdate', marker='o', linewidth=2.5)
plt.title('Hourly Bike Demand Profile: Weekday vs Weekend', fontsize=14)
plt.xlabel('Hour of Day (0-23)', fontsize=12)
plt.ylabel('Total Bike Rides', fontsize=12)
plt.xticks(range(0, 24))
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend(title='Day Type')
plt.show()

# %% [markdown]
# ### Correlation

# %%
features = [
    'dist_to_nearest_cafe', 'dist_to_nearest_bank', 'dist_to_nearest_university',
    'dist_to_nearest_station', 'dist_to_nearest_pub', 'dist_to_nearest_supermarket'
]

agg_dict = {
    "count": "sum",
    "dist_to_nearest_cafe": "first",
    "dist_to_nearest_bank": "first",
    "dist_to_nearest_university": "first",
    "dist_to_nearest_station": "first",
    "dist_to_nearest_pub": "first",
    "dist_to_nearest_supermarket": "first"
}




temp_df = df[features + ['count'] + ['start_station_number']].groupby("start_station_number").agg(agg_dict).reset_index().drop(axis=1, columns=["start_station_number"])

plt.figure(figsize=(12,8))
sns.heatmap(temp_df.corr(), annot=True, cmap='coolwarm')
plt.title("Correlation")

plt.show()

# %% [markdown]
# ### Distribution Of Amenity Densities

# %%
figure, axis = plt.subplots(2, 3)
axis[0, 0].hist(df["dist_to_nearest_cafe"], bins=30)
axis[0, 0].set_title("dist_to_nearest_cafe")

axis[0, 1].hist(df["dist_to_nearest_bank"], bins=30)
axis[0, 1].set_title("dist_to_nearest_bank")

axis[0, 2].hist(df["dist_to_nearest_university"], bins=30)
axis[0, 2].set_title("dist_to_nearest_university")

axis[1, 0].hist(df["dist_to_nearest_station"], bins=30)
axis[1, 0].set_title("dist_to_nearest_station")

axis[1, 1].hist(df["dist_to_nearest_pub"], bins=30)
axis[1, 1].set_title("dist_to_nearest_pub")

axis[1, 2].hist(df["dist_to_nearest_supermarket"], bins=30)
axis[1, 2].set_title("dist_to_nearest_supermarket")

plt.subplots_adjust(
    left=0.1,    # The left side of the subplots of the figure
    right=0.9,   # The right side of the subplots of the figure
    bottom=0.1,  # The bottom of the subplots of the figure
    top=0.9,     # The top of the subplots of the figure
    wspace=1,  # The amount of width reserved for blank space between subplots
    hspace=0.6   # The amount of height reserved for white space between subplots
)

plt.show()

# %%
# !pip install folium (if not already installed)
import folium
import numpy as np

target_lon = -0.09844180843941625
target_lat = 51.51370562455308

# Aggregate total counts and get unique coordinates per station
station_map_df = df.groupby(['start_station_number', 'latitude', 'longitude'])['count'].sum().reset_index()

# Initialize the map centered around London
london_map = folium.Map(location=[target_lat, target_lon], zoom_start=13, tiles='cartodbpositron')

folium.CircleMarker(
        location=[target_lat, target_lon],
        color='#b43d1f',
        popup="Reference Coordinate",
        fill=True,
        fill_color="#b43d1f",
        fill_opacity=1,
        weight=1
    ).add_to(london_map)

# Add scaled circle markers for each station
for idx, row in station_map_df.iterrows():
    folium.CircleMarker(
        location=[row['latitude'], row['longitude']],
        # Scale the radius logarithmically so highly used stations don't cover the entire map
        radius=np.log1p(row['count']) * 1.5,
        popup=f"Station ID: {row['start_station_number']}<br>Total Rides: {row['count']}",
        tooltip=f"Station {row['start_station_number']}",
        color='#1f77b4',
        fill=True,
        fill_color='#1f77b4',
        fill_opacity=0.6,
        weight=1
    ).add_to(london_map)

# Display the map in the notebook
london_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bcf5d4834156da7ee381defbaefa4bde {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bcf5d4834156da7ee381defbaefa4bde&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bcf5d4834156da7ee381defbaefa4bde = L.map(
#                 &quot;map_bcf5d4834156da7ee381defbaefa4bde&quot;,
#                 {
#                     center: [51.51370562455308, -0.09844180843941625],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_69375feac3f710cb7b023846e4d7d88f = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_69375feac3f710cb7b023846e4d7d88f.addTo(map_bcf5d4834156da7ee381defbaefa4bde);
#
#
#             var circle_marker_77e180fc8bbd723a7f9511f715586ba0 = L.circleMarker(
#                 [51.51370562455308, -0.09844180843941625],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#b43d1f&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#b43d1f&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_bcf5d4834156da7ee381defbaefa4bde);
#
#
#         var popup_ca3cee05b07dc3283de3c86b47b913b9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_144793f166cf33572b82819ac221b014 = $(`&lt;div id=&quot;html_144793f166cf33572b82819ac221b014&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Reference Coordinate&lt;/div&gt;`)[0];
#                 popup_ca3cee05b07dc3283de3c86b47b913b9.setContent(html_144793f166cf33572b82819ac221b014);
#
#
#
#         circle_marker_77e180fc8bbd723a7f9511f715586ba0.bindPopup(popup_ca3cee05b07dc3283de3c86b47b913b9)
#         ;
#
#
#
#
#             var circle_marker_53dbbd932b58b9e1de745f476a44db4d = L.circleMarker(
#                 [51.50724437, -0.106237501],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1f77b4&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#1f77b4&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 12.001027176772123, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_bcf5d4834156da7ee381defbaefa4bde);
#
#
#         var popup_29dcf08e85761af61a979d9c0b20f22e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_35331425ceb82b3b7fd9a75af7f503b4 = $(`&lt;div id=&quot;html_35331425ceb82b3b7fd9a75af7f503b4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Station ID: 959.0&lt;br&gt;Total Rides: 2982.0&lt;/div&gt;`)[0];
#                 popup_29dcf08e85761af61a979d9c0b20f22e.setContent(html_35331425ceb82b3b7fd9a75af7f503b4);
#
#
#
#         circle_marker_53dbbd932b58b9e1de745f476a44db4d.bindPopup(popup_29dcf08e85761af61a979d9c0b20f22e)
#         ;
#
#
#
#
#             circle_marker_53dbbd932b58b9e1de745f476a44db4d.bindTooltip(
#                 `&lt;div&gt;
#                      Station 959.0
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_f1f585055d5c9ec1c820a4d88d95c296 = L.circleMarker(
#                 [51.50462759, -0.091773776],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1f77b4&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#1f77b4&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 13.52094068689678, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_bcf5d4834156da7ee381defbaefa4bde);
#
#
#         var popup_e2cd17f521860e746a3a9aee57450cfd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_de2f419b8af02fb2239f9e1c1bb6b235 = $(`&lt;div id=&quot;html_de2f419b8af02fb2239f9e1c1bb6b235&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Station ID: 960.0&lt;br&gt;Total Rides: 8216.0&lt;/div&gt;`)[0];
#                 popup_e2cd17f521860e746a3a9aee57

# %%
top_stations = df.groupby('start_station_number')['count'].sum().sort_values(ascending=False).head(10).reset_index()
# Convert to string to treat station numbers as categorical labels
top_stations['start_station_number'] = top_stations['start_station_number'].astype(str)

plt.figure(figsize=(10, 6))
sns.barplot(data=top_stations, x='count', y='start_station_number', palette='viridis')
plt.title('Top 10 Busiest Start Stations', fontsize=14)
plt.xlabel('Total Rides', fontsize=12)
plt.ylabel('Station ID', fontsize=12)
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_1072\3396930615.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=top_stations, x='count', y='start_station_number', palette='viridis')
